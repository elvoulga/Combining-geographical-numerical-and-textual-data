# %% [markdown]
# ## Combining geographical numerical and textual data
#
# In this assignment you will combine weather and geonames data to find Europe's windiest cities.

# %% [markdown]
# Open a terminal and issue the following commands:
#
# `$ conda install basemap
# $ pip install wget
# `
#
# Accept all to install the extra packages required.

# %%
import sys 
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import wget
import csv
import os.path
from enum import Enum
import ast
import datetime
import heapq
import math
import itertools
from numpy import unravel_index
from sklearn.utils.extmath import cartesian
csv.field_size_limit(sys.maxsize)
# Out:
# 131072

# %% [markdown]
# For this assignment you will need to download the following 3 files. The first one is ~343MB.
#
# http://iit.demokritos.gr/~iaklampanos/assign3_data_v2.npz
#
# http://iit.demokritos.gr/~iaklampanos/lat.npy
#
# http://iit.demokritos.gr/~iaklampanos/lon.npy
#
# http://download.geonames.org/export/dump/cities5000.zip

# %% [markdown]
# **(1) Write a generic function to download a file from the Web (given a URL), if it is not already present locally. The function should be parameterisable w.r.t. the local directory to be used, the default being the current working directory (`./`). Use this function to assign values to variables `data_filename`, `lat_filename` and `lon_filename`. [2 marks]**
#
# *Hint: Use the wget package.*
#
# *Hint: When developing use the smaller `lat.npy` or `lon.npy`.*
#
# *Optional: Implement a function to allow wget to display the download progress in %. Try to find your way using `help(wget)` and by looking up the source code of wget online.*

# %%
def fetch_data(web_file, local_dir='.'):
    """Download the `web_file`, assuming it is a web resource into the local_dir. 
    If a file with the same filename already exists in the local directory, do not 
    download it but return its path instead.
    Arguments:
        web_file: a web resource identifiable by a url (str)
        local_dir: a local directory to download the web_file into (str)
    Return: The local path to the file (str)
    """
    import click
    file_name = wget.detect_filename(web_file) #tou dineis url, sou epistrefei filename
   
    file_path = os.path.join(local_dir, file_name)
    
    if os.path.exists(file_path) == False:
        down_file = wget.download(web_file)
        return down_file
    else:
        pass

data_filename = fetch_data('http://iit.demokritos.gr/~iaklampanos/assign3_data_v2.npz') or 'assign3_data_v2.npz'
lat_filename = fetch_data('http://iit.demokritos.gr/~iaklampanos/lat.npy') or 'lat.npy'
lon_filename = fetch_data('http://iit.demokritos.gr/~iaklampanos/lon.npy') or 'lon.npy'
cities_filename = fetch_data('http://download.geonames.org/export/dump/cities5000.zip') or 'cities5000.zip'

# %% [markdown]
# The first three pieces of data you have downloaded are all numpy arrays which you can deserialise using `np.load`, as shown below.

# %%
data = np.load(data_filename)['c137']
lat = np.load(lat_filename)
lon = np.load(lon_filename)

# %% [markdown]
# The geonames data (`cities5000.zip`) contains a text file (`cities5000.txt`) of tab-separated values. The description of this data is at http://download.geonames.org/export/dump/readme.txt. It lists the geographical locations and names of the cities with a population > 5000.
#
# **Unzip `cities5000.zip` to obtain `cities5000.txt`.**

# %% [markdown]
# ** (2) In this exercise we will need to extract the fields geonamesid, name, asciiname,
# latitude, longitude, country code, population, elevation, dem and time zone (10 in total). Write a (*very* basic) class providing a human-readable enumeration to the fields above, corresponding to the format of the `cities5000.txt` file. [2 marks] **
#
# *Hint: e.g. for the field time zone, which is the 17th field in the file, we want to write F.TZ instead of 17. This will make our code more readable and more maintainable (e.g. in case the format changes in the future).*

# %%
class F():
    geonamesid = 0
    name = 1
    asciiname = 2
    latitude = 4
    longitude = 5
    country_code = 8
    population = 14
    elevation = 16
    dem = 17
    time_zone = 18

# %% [markdown]
# ** (3) Write a function to read cities5000.txt into a Python list, retaining the fields geonamesid, name, asciiname, latitude, longitude, contry code, population, elevation, dem and time zone. Use the class you defined above. [2 marks] **

# %%
def load_cities(filename='cities5000.csv'):
    """Parse cities5000.txt and return a list containing a subset of its fields."""
    cities_list = []
    f = F()
    
    with open(filename) as csvfile:
        readCSV = csv.reader(csvfile, delimiter='\t',quoting=csv.QUOTE_NONE)
        for row in readCSV:
            cities_list.append((row[f.geonamesid], row[f.name], row[f.asciiname], row[f.latitude], row[f.longitude], 
                                row[f.country_code], row[f.population], row[f.elevation], row[f.dem], row[f.time_zone]))
    return cities_list

# %%
cities = load_cities()
len(cities)
# Out:
# 48321

# %% [markdown]
# **(4) Write a function that given a list of cities in the format above it selects cities based on their latitude and longitude, and minimum population. We want all cities within two pairs of (lat,long), with a population >= `population`. Use your function to get all european cities (coordinates provided below) with a population >= 100000 [2 marks] **

# %%
def latlong_filter(lat1, lon1, lat2, lon2, population, cities=cities):
    """Return a sublist of the geonames cities from a northwestern point (`lat1`, `lon1`) 
       to a southeastern point (`lat2`, `lon2`) and with a minimum population of `population`
    """
    european_cities = [city for city in cities if float(city[6]) >= float(population) and float(city[3]) <= float(lat1)
                       and float(city[3]) >= float(lat2) and float(city[4]) >= float(lon1) and float(city[4]) <= float(lon2)]
    return european_cities

LAT1 = 58.070942
LON1 = -9.493621
LAT2 = 34.103214
LON2 = 29.686365
european_cities = latlong_filter(LAT1, LON1, LAT2, LON2, 100000)
len(european_cities)
# Out:
# 670

# %% [markdown]
# Back to the `data` variable... `data` has been previously used in a classification experiment and has a complicated structure. We will use only part of it. Each row has 5 data fields:
# * [0] a human-readable name
# * [1] an id
# * [2] a date & time
# * [3] a 501x501 shape
# * [4] a 3x3x64x64 shape
#
# For our exercise we will use fields 2, the datetime, and 4. 4 corresponds to weather snapshots averaged over 78hr periods (3 days and 6hrs). Datetimes and weathers repeat over 2-year periods. We need to extract the datetimes and their corresponding weathers over a 2-year period, ignoring the rest. This corresponds to 224 records (rows).

# %% [markdown]
# **(5) Complete the function below, which should return a *copy* of the first 224 rows of `data` retaining only datetimes and weather. [2 marks]**

# %%
def extract_time_weather(data=data, rows=224):
    data = data[:rows, [2,4]]
    return data
times_weathers = extract_time_weather()
#assert(times_weathers[0,1][0,0].shape == (64, 64))
print times_weathers.shape

# reshape times andd weathers
times = np.zeros((224,),dtype = datetime.datetime)
weathers = np.zeros((224,3,3,64,64))
    
for index in range(len(times_weathers)):
    times[index] = times_weathers[index][0]
    weathers[index] = times_weathers[index][1]

weathers.shape
# Out:
# (224, 2)
# (224, 3, 3, 64, 64)

# %% [markdown]
# The weather component of our data has a shape 3, 3, 64, 64. This corresponds to 3 variables (west-east wind component, south-north wind component, geopotential height), estimated at 3 pressure levels (500, 700, 900 hPa) respectively. The values are provided on a coarse 64x64 grid covering Europe.
#
# We will use wind information and our cities to find the windiest European cities per year season. But first we need to be able to find the cell, in the 64x64 image, which contains a location given a latitude, longitude.

# %% [markdown]
# **(6) Complete the function below to convert a latitude, longitude pair into a pair of integers corresponding to the geographical point's coordinates in the 64x64 space. [2 marks]**
#
# *Hint: `convert_to_xy(latitude, longitude) -> x(0-63), y(0, 63)`*
#
# *Hint: use the `lon` and `lat` arrays defined above. Find the indexes of the input cell that is the closest to the arguments. Use the **`haversine()`** distance function provided below.*

# %%
def haversine(lat1, lon1, lat2, lon2):
    """
    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees)

    All args must be of equal length.    
    (https://stackoverflow.com/questions/29545704/fast-haversine-approximation-python-pandas)
    """
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2
    c = 2 * np.arcsin(np.sqrt(a))
    km = 6367 * c
    return km

def convert_to_xy(latitude, longitude):
    """Map the coordinate provided (`latitude`, `longitude`) onto the weather 64x64 grid."""
    distance = 10000000000
    
    for i in range(64):
        for j in range(64):
            distance_new  = haversine(latitude, longitude, float(lat[i][j]), float(lon[i][j]))
            if distance_new < distance:
                distance = distance_new
                x, y = (i, j)
                
    return x, y

# %% [markdown]
# **(7) Calculate the wind magnitude and append it into our wind data array. This array must have the same shape as the u- and v-wind component arrays [2] **
#
# *Hint: The magnitudes should have a shape of 3x64x64, i.e. each wind magnitude array (64x64) should correspond to a different pressure level (3 levels in total).*

# %%
all_weathers_mags = np.sqrt([measure[0]**2 + measure[1]**2 for measure in weathers])
all_weathers_mags.shape
# Out:
# (224, 3, 64, 64)

# %% [markdown]
# **(8) Calculate the average wind magnitude per season - quarters. Remember that our overall data cover 2 years [2 marks]**

# %%
quarter = 28
whole = 112

magnitude_averages = [np.mean([np.mean(all_weathers_mags[c*quarter:((c+1)*quarter)]),\
                         np.mean(all_weathers_mags[whole+(c*quarter):((c+1)*quarter+whole)])]) for c in range(4)]
magnitude_averages
# Out:
# [27.533729150182563, 14.5821676338708, 14.21918990348229, 24.046576946650298]

# %% [markdown]
# **(9) Using the list of `european_cities` you calculated above, find the 10 windiest cities - i.e. the cities which are located in the cell with the highest magnitude - per season. Make sure you retain their indexes in `european_cities`, or that you also store their geolocation. Take into account only the 900hPa pressure level. [2 marks]**
#
# *Hint: You may want to create a function to avoid repeating code. You will also need to use the function `convert_to_xy` you created above*

# %%
cities_grid = []

for city in european_cities:
    x,y = convert_to_xy(float(city[3]), float(city[4]))
    city_tuple = (x, y, city[2], city[3], city[4])
    cities_grid.append(city_tuple)
cities_grid
# Out:
# [(15, 37, 'Elbasan', '41.1125', '20.08222'),
#  (15, 37, 'Tirana', '41.3275', '19.81889'),
#  (15, 36, 'Durres', '41.32306', '19.44139'),
#  (25, 33, 'Vienna', '48.20849', '16.37208'),
#  (24, 30, 'Salzburg', '47.79941', '13.04399'),
#  (25, 31, 'Linz', '48.30639', '14.28611'),
#  (23, 28, 'Innsbruck', '47.26266', '11.39454'),
#  (23, 32, 'Graz', '47.06667', '15.45'),
#  (19, 35, 'Zenica', '44.20169', '17.90397'),
#  (19, 35, 'Tuzla', '44.53842', '18.66709'),
#  (18, 35, 'Sarajevo', '43.84864', '18.35644'),
#  (18, 34, 'Mostar', '43.34333', '17.80806'),
#  (20, 34, 'Banja Luka', '44.77842', '17.19386'),
#  (29, 22, 'Namur', '50.4669', '4.86746'),
#  (29, 23, 'Liege', '50.63373', '5.56749'),
#  (30, 21, 'Gent', '51.05', '3.71667'),
#  (29, 22, 'Charleroi', '50.41136', '4.44448'),
#  (29, 22, 'Brussels', '50.85045', '4.34878'),
#  (30, 21, 'Brugge', '51.20892', '3.22424'),
#  (30, 22, 'Antwerpen', '51.21989', '4.40346'),
#  (19, 45, 'Varna', '43.21667', '27.91667'),
#  (17, 43, 'Stara Zagora', '42.43278', '25.64194'),
#  (17, 40, 'Sofia', '42.69751', '23.32415'),
#  (19, 43, 'Ruse', '43.85639', '25.97083'),
#  (17, 42, 'Plovdiv', '42.15', '24.75'),
#  (18, 42, 'Pleven', '43.41667', '24.61667'),
#  (18, 45, 'Burgas', '42.50606', '27.46781'),
#  (32, 42, 'Salihorsk', '52.7876', '27.5415'),
#  (31, 41, 'Pinsk', '52.1229', '26.0951'),
#  (34, 42, 'Novoye Medvezhino', '53.88333', '27.45'),
#  (36, 42, 'Navapolatsk', '55.5318', '28.5987'),
#  (34, 42, 'Minsk', '53.9', '27.56667'),
#  (31, 44, 'Mazyr', '52.0495', '29.2456'),
#  (34, 41, 'Maladzyechna', '54.3167', '26.854'),
#  (33, 39, 'Hrodna', '53.6884', '23.8258'),
#  (31, 39, 'Brest', '52.09755', '23.68775'),
#  (34, 43, 'Horad Barysaw', '54.2279', '28.505'),
#  (32, 41, 'Baranovichi', '53.1327', '26.0139'),
#  (33, 44, 'Babruysk', '53.1384', '29.2214'),
#  (34, 42, 'Malinovka', '53.8579', '27.4374'),
#  (24, 25, 'Zurich', '47.36667', '8.55'),
#  (23, 23, 'Lausanne', '46.516', '6.63282'),
#  (22, 23, 'Geneve', '46.20222', '6.14569'),
#  (23, 24, 'Bern', '46.94809', '7.44744'),
#  (24, 24, 'Basel', '47.55839', '7.57327'),
#  (27, 31, 'Prague', '50.08804', '14.42076'),
#  (27, 30, 'Pilsen', '49.74747', '13.37759'),
#  (27, 35, 'Ostrava', '49.83465', '18.28204'),
#  (27, 34, 'Olomouc', '49.59552', '17.25175'),
#  (26, 33, 'Brno', '49.19522', '16.60796'),
#  (27, 27, 'Wuerzburg', '49.79391', '9.95121'),
#  (29, 24, 'Wuppertal', '51.27027', '7.16755'),
#  (31, 28, 'Wolfsburg', '52.42452', '10.7815'),
#  (30, 25, 'Witten', '51.44362', '7.35258'),
#  (28, 25, 'Wiesbaden', '50.08258', '8.24932'),
#  (25, 27, 'Ulm', '48.39841', '9.99155'),
#  (27, 24, 'Trier', '49.75565', '6.63935'),
#  (26, 26, 'Stuttgart', '48.78232', '9.17702'),
#  (29, 24, 'Solingen', '51.17343', '7.0845'),
#  (29, 25, 'Siegen', '50.87481', '8.02431'),
#  (31, 30, 'Schoneberg Bezirk', '52.46667', '13.35'),
#  (30, 27, 'Salzgitter', '52.15705', '10.4154'),
#  (27, 24, 'Saarbruecken', '49.23262', '7.00982'),
#  (33, 29, 'Rostock', '54.0887', '12.14049'),
#  (25, 26, 'Reutlingen', '48.49144', '9.20427'),
#  (29, 25, 'Remscheid', '51.17983', '7.1925'),
#  (26, 29, 'Regensburg', '49.01513', '12.10161'),
#  (30, 25, 'Recklinghausen', '51.61379', '7.19738'),
#  (31, 30, 'Prenzlauer Berg Bezirk', '52.53878', '13.42443'),
#  (31, 30, 'Potsdam', '52.39886', '13.06566'),
#  (26, 26, 'Pforzheim', '48.88436', '8.69892'),
#  (30, 26, 'Paderborn', '51.71905', '8.75439'),
#  (31, 25, 'Osnabrueck', '52.27264', '8.0498'),
#  (32, 26, 'Oldenburg', '53.14118', '8.21467'),
#  (28, 26, 'Offenbach', '50.10061', '8.76647'),
#  (30, 24, 'Oberhausen', '51.47805', '6.8625'),
#  (27, 28, 'Nuernberg', '49.45421', '11.07752'),
#  (29, 24, 'Nippes', '50.96545', '6.95314'),
#  (30, 29, 'Neue Neustadt', '52.15', '11.63333'),
#  (29, 24, 'Neuss', '51.19807', '6.68504'),
#  (30, 25, 'Muenster', '51.96236', '7.62571'),
#  (25, 28, 'Munich', '48.13743', '11.57549'),
#  (30, 24, 'Muelheim', '51.43218', '6.87967'),
#  (29, 24, 'Moenchengladbach', '51.18539', '6.44172'),
#  (30, 24, 'Moers', '51.45342', '6.6326'),
#  (31, 30, 'Marzahn', '52.54525', '13.56983'),
#  (27, 25, 'Mannheim', '49.4891', '8.46694'),
#  (27, 25, 'Mainz', '49.98419', '8.2791'),
#  (30, 29, 'Magdeburg', '52.12773', '11.62916'),
#  (27, 25, 'Ludwigshafen am Rhein', '49.48121', '8.44641'),
#  (33, 28, 'Luebeck', '53.86893', '10.68729'),
#  (29, 24, 'Leverkusen', '51.0303', '6.98432'),
#  (29, 29, 'Leipzig', '51.33962', '12.37129'),
#  (31, 30, 'Bezirk Kreuzberg', '52.49973', '13.40338'),
#  (30, 24, 'Krefeld', '51.33645', '6.55381'),
#  (29, 24, 'Koeln', '50.93333', '6.95'),
#  (28, 25, 'Koblenz', '50.35357', '7.57883'),
#  (34, 27, 'Kiel', '54.32133', '10.13489'),
#  (29, 27, 'Kassel', '51.31667', '9.5'),
#  (26, 25, 'Karlsruhe', '49.00937', '8.40444'),
#  (29, 28, 'Jena', '50.92878', '11.5899'),
#  (26, 28, 'Ingolstadt', '48.76508', '11.42372'),
#  (30, 27, 'Hildesheim', '52.15077', '9.95112'),
#  (30, 25, 'Herne', '51.5388', '7.22572'),
#  (26, 26, 'Heilbronn', '49.13995', '9.22054'),
#  (27, 26, 'Heidelberg', '49.40768', '8.69079'),
#  (32, 27, 'Harburg', '53.46057', '9.98388'),
#  (31, 27, 'Hannover', '52.37052', '9.73322'),
#  (30, 25, 'Hamm', '51.68033', '7.82089'),
#  (32, 27, 'Wandsbek', '53.58334', '10.08305'),
#  (32, 27, 'Marienthal', '53.56667', '10.08333'),
#  (32, 27, 'Hamburg-Mitte', '53.55', '10.01667'),
#  (32, 27, 'Eimsbuettel', '53.57416', '9.95679'),
#  (32, 27, 'Altona', '53.55', '9.93333'),
#  (32, 27, 'Hamburg', '53.57532', '10.01534'),
#  (29, 29, 'Halle (Saale)', '51.48158', '11.97947'),
#  (30, 25, 'Hagen', '51.36081', '7.47168'),
#  (30, 27, 'Goettingen', '51.53443', '9.93228'),
#  (29, 29, 'Gera', '50.88029', '12.08187'),
#  (30, 24, 'Gelsenkirchen', '51.50508', '7.09654'),
#  (27, 28, 'Furth', '49.47593', '10.98856'),
#  (31, 30, 'Friedrichshain Bezirk', '52.51559', '13.45482'),
#  (25, 25, 'Freiburg', '47.9959', '7.85222'),
#  (28, 26, 'Frankfurt am Main', '50.11552', '8.68417'),
#  (30, 24, 'Essen', '51.45657', '7.01228'),
#  (27, 28, 'Erlangen', '49.59099', '11.00783'),
#  (29, 28, 'Erfurt', '50.9787', '11.03283'),
#  (29, 24, 'Duesseldorf', '51.22172', '6.77616'),
#  (30, 24, 'Duisburg', '51.43247', '6.76516'),
#  (29, 30, 'Dresden', '51.05089', '13.73832'),
#  (30, 25, 'Dortmund', '51.51494', '7.466'),
#  (27, 26, 'Darmstadt', '49.87167', '8.65027'),
#  (28, 30, 'Chemnitz', '50.8357', '12.92922'),
#  (31, 30, 'Charlottenburg Bezirk', '52.51667', '13.28333'),
#  (33, 26, 'Bremerhaven', '53.55021', '8.57673'),
#  (32, 26, 'Bremen', '53.07516', '8.80777'),
#  (31, 28, 'Braunschweig', '52.26594', '10.52673'),
#  (30, 24, 'Bottrop', '51.52392', '6.9285'),
#  (29, 24, 'Bonn', '50.73438', '7.09549'),
#  (30, 25, 'Bochum', '51.48165', '7.21648'),
#  (30, 26, 'Bielefeld', '52.03333', '8.53333'),
#  (31, 30, 'Berlin', '52.52437', '13.41053'),
#  (29, 24, 'Bergisch Gladbach', '50.9856', '7.13298'),
#  (25, 28, 'Augsburg', '48.37154', '10.89851'),
#  (29, 23, 'Aachen', '50.77664', '6.08342'),
#  (30, 25, 'Bochum-Hordel', '51.50168', '7.1756'),
#  (32, 27, 'Bergedorf', '53.48462', '10.22904'),
#  (31, 30, 'Berlin Schoeneberg', '52.48388', '13.3477'),
#  (32, 27, 'Hamburg-Nord', '53.58935', '9.984'),
#  (35, 28, 'Odense', '55.39594', '10.38831'),
#  (35, 30, 'Copenhagen', '55.67594', '12.56553'),
#  (36, 28, 'Arhus', '56.15674', '10.21076'),
#  (37, 28, 'Aalborg', '57.048', '9.9187'),
#  (9, 18, 'Boumerdas', '36.76639', '3.47717'),
#  (7, 12, 'Tlemcen', '34.87833', '-1.315'),
#  (9, 18, 'Tizi Ouzou', '36.71182', '4.04591'),
#  (7, 15, 'Tiaret', '35.37103', '1.31699'),
#  (6, 23, 'Tebessa', '35.40417', '8.12417'),
#  (8, 23, 'Souk Ahras', '36.28639', '7.95111'),
#  (9, 22, 'Skikda', '36.87617', '6.90921'),
#  (8, 12, 'Sidi Bel Abbes', '35.18994', '-0.63085'),
#  (8, 20, 'Setif', '36.19112', '5.41373'),
#  (7, 13, 'Saida', '34.83033', '0.15171'),
#  (8, 14, 'Relizane', '35.73734', '0.55599'),
#  (7, 22, 'Oum el Bouaghi', '35.87541', '7.11353'),
#  (8, 13, 'Oran', '35.69906', '-0.63588'),
#  (7, 19, "M'Sila", '35.70583', '4.54194'),
#  (9, 14, 'Mostaganem', '35.93115', '0.08918'),
#  (8, 17, 'Medea', '36.26417', '2.75393'),
#  (8, 13, 'Mascara', '35.39664', '0.14027'),
#  (6, 22, 'Khenchela', '35.43583', '7.14333'),
#  (9, 21, 'Jijel', '36.82055', '5.76671'),
#  (8, 22, 'Guelma', '36.46214', '7.42608'),
#  (8, 20, 'El Eulma', '36.15281', '5.69016'),
#  (9, 15, 'Chlef', '36.16525', '1.33452'),
#  (8, 19, 'El Achir', '36.06386', '4.62744'),
#  (9, 15, 'Ech Chettia', '36.19591', '1.25537'),
#  (6, 17, 'Djelfa', '34.67279', '3.263'),
#  (8, 21, 'Constantine', '36.365', '6.61472'),
#  (9, 17, 'Bordj el Kiffan', '36.74871', '3.19249'),
#  (8, 19, 'Bordj Bou Arreridj', '36.07321', '4.76108'),
#  (9, 17, 'Blida', '36.47004', '2.8277'),
#  (6, 20, 'Biskra', '34.85038', '5.72805'),
#  (9, 20, 'Bejaia', '36.75587', '5.08433'),
#  (7, 21, 'Batna', '35.55597', '6.17414'),
#  (9, 17, 'Baraki', '36.66655', '3.09606'),
#  (9, 17, 'Bab Ezzouar', '36.72615', '3.18291'),
#  (9, 23, 'Annaba', '36.9', '7.76667'),
#  (9, 17, 'Algiers', '36.73225', '3.08746'),
#  (7, 17, 'Ain Oussera', '35.45139', '2.90583'),
#  (7, 22, 'Ain Beida', '35.79639', '7.39278'),
#  (14, 14, 'Valencia', '39.46975', '-0.37739'),
#  (12, 13, 'Torrevieja', '37.97872', '-0.68222'),
#  (12, 7, 'Sevilla', '37.38283', '-5.97317'),
#  (13, 18, 'Palma', '39.56939', '2.65024'),
#  (12, 13, 'Murcia', '37.98704', '-1.13004'),
#  (11, 8, 'Marbella', '36.51543', '-4.88583'),
#  (11, 9, 'Malaga', '36.72016', '-4.42034'),
#  (12, 7, 'Jerez de la Frontera', '36.68645', '-6.13606'),
#  (12, 10, 'Jaen', '37.76922', '-3.79028'),
#  (13, 6, 'Huelva', '37.26638', '-6.94004'),
#  (11, 10, 'Granada', '37.18817', '-3.60667'),
#  (12, 13, 'Elche', '38.26218', '-0.70107'),
#  (12, 7, 'Dos Hermanas', '37.28287', '-5.92088'),
#  (13, 9, 'Cordoba', '37.89155', '-4.77275'),
#  (14, 15, 'Castello de la Plana', '39.98567', '-0.04935'),
#  (11, 13, 'Cartagena', '37.60512', '-0.98623'),
#  (11, 6, 'Cadiz', '36.52672', '-6.2891'),
#  (15, 7, 'Badajoz', '38.87789', '-6.97061'),
#  (11, 11, 'Almeria', '36.83814', '-2.45974'),
#  (12, 14, 'Alicante', '38.34517', '-0.48149'),
#  (11, 7, 'Algeciras', '36.13326', '-5.45051'),
#  (14, 12, 'Albacete', '38.99424', '-1.85643'),
#  (17, 14, 'Zaragoza', '41.65606', '-0.87734'),
#  (19, 13, 'Gasteiz / Vitoria', '42.84998', '-2.67268'),
#  (16, 11, 'Villaverde', '40.35', '-3.7'),
#  (20, 6, 'Vigo', '42.23282', '-8.72264'),
#  (18, 10, 'Valladolid', '41.65518', '-4.72372'),
#  (16, 11, 'Torrejon de Ardoz', '40.45535', '-3.46973'),
#  (16, 11, 'Tetuan de las Victorias', '40.45975', '-3.6975'),
#  (16, 17, 'Terrassa', '41.56667', '2.01667'),
#  (16, 16, 'Tarragona', '41.11667', '1.25'),
#  (20, 12, 'Santander', '43.46472', '-3.80444'),
#  (16, 18, 'Santa Coloma de Gramenet', '41.45152', '2.2081'),
#  (20, 14, 'San Sebastian', '43.31283', '-1.97499'),
#  (16, 18, 'Sant Andreu', '41.43541', '2.18982'),
#  (17, 9, 'Salamanca', '40.96882', '-5.66388'),
#  (16, 17, 'Sabadell', '41.54329', '2.10942'),
#  (16, 16, 'Reus', '41.15612', '1.10687'),
#  (16, 11, 'Puente de Vallecas', '40.39354', '-3.662'),
#  (16, 11, 'Parla', '40.23604', '-3.76752'),
#  (19, 14, 'Pamplona', '42.81687', '-1.64323'),
#  (21, 10, 'Oviedo', '43.36029', '-5.84476'),
#  (20, 7, 'Ourense', '42.33669', '-7.86407'),
#  (16, 11, 'Mostoles', '40.32234', '-3.86496'),
#  (16, 11, 'Moratalaz', '40.40742', '-3.64935'),
#  (16, 18, 'Mataro', '41.54211', '2.4445'),
#  (16, 11, 'Madrid', '40.4165', '-3.70256'),
#  (19, 13, 'Logrono', '42.46667', '-2.45'),
#  (17, 16, 'Lleida', '41.61674', '0.62218'),
#  (20, 10, 'Leon', '42.60003', '-5.57032'),
#  (16, 11, 'Leganes', '40.32718', '-3.7635'),
#  (22, 7, 'A Coruna', '43.37135', '-8.396'),
#  (16, 17, "L'Hospitalet de Llobregat", '41.35967', '2.10028'),
#  (16, 11, 'Hortaleza', '40.47444', '-3.6411'),
#  (16, 17, 'Gracia', '41.40237', '2.15641'),
#  (21, 10, 'Gijon', '43.53573', '-5.66152'),
#  (16, 11, 'Getafe', '40.30571', '-3.73295'),
#  (16, 11, 'Fuenlabrada', '40.28419', '-3.79415'),
#  (16, 11, 'Ciudad Lineal', '40.44505', '-3.65132'),
#  (16, 11, 'Chamartin', '40.46206', '-3.6766'),
#  (19, 12, 'Burgos', '42.34106', '-3.70184'),
#  (20, 13, 'Bilbao', '43.26271', '-2.92528'),
#  (16, 17, 'Barcelona', '41.38879', '2.15899'),
#  (16, 18, 'Badalona', '41.45004', '2.24741'),
#  (16, 11, 'Alcorcon', '40.34582', '-3.82487'),
#  (16, 11, 'Alcobendas', '40.54746', '-3.64197'),
#  (16, 11, 'Alcala de Henares', '40.48205', '-3.35996'),
#  (16, 18, 'Nou Barris', '41.44163', '2.17727'),
#  (16, 11, 'Moncloa-Aravaca', '40.43547', '-3.7317'),
#  (16, 17, 'Eixample', '41.38896', '2.16179'),
#  (16, 17, 'Sarria-Sant Gervasi', '41.40104', '2.1394'),
#  (16, 17, 'Horta-Guinardo', '41.41849', '2.1677'),
#  (16, 17, 'Sants-Montjuic', '41.37263', '2.1546'),
#  (16, 18, 'Sant Marti', '41.41814', '2.19933'),
#  (16, 17, 'Ciutat Vella', '41.38022', '2.17319'),
#  (16, 11, 'Arganzuela', '40.40021', '-3.69618'),
#  (16, 11, 'San Blas-Canillejas', '40.43893', '-3.61537'),
#  (16, 11, 'Latina', '40.38897', '-3.74569'),
#  (16, 11, 'Usera', '40.38866', '-3.70035'),
#  (16, 11, 'Salamanca', '40.42972', '-3.67975'),
#  (16, 11, 'Chamberi', '40.43404', '-3.70379'),
#  (16, 11, 'Carabanchel', '40.39094', '-3.7242'),
#  (16, 11, 'City Center', '40.41831', '-3.70275'),
#  (16, 11, 'Retiro', '40.41317', '-3.68307'),
#  (17, 14, 'Delicias', '41.64928', '-0.90757'),
#  (16, 11, 'Fuencarral-El Pardo', '40.4984', '-3.7314'),
#  (22, 21, 'Villeurbanne', '45.76667', '4.88333'),
#  (25, 18, 'Tours', '47.38333', '0.68333'),
#  (19, 17, 'Toulouse', '43.60426', '1.44367'),
#  (18, 22, 'Toulon', '43.12442', '5.92836'),
#  (26, 25, 'Strasbourg', '48.58392', '7.74553'),
#  (21, 21, 'Saint-Etienne', '45.43389', '4.39'),
#  (28, 19, 'Rouen', '49.44313', '1.09932'),
#  (26, 16, 'Rennes', '48.11198', '-1.67429'),
#  (27, 21, 'Reims', '49.25', '4.03333'),
#  (18, 19, 'Perpignan', '42.69764', '2.89541'),
#  (27, 20, 'Paris', '48.85341', '2.3488'),
#  (25, 19, 'Orleans', '47.90289', '1.90389'),
#  (19, 20, 'Nimes', '43.83333', '4.35'),
#  (19, 23, 'Nice', '43.70313', '7.26608'),
#  (25, 15, 'Nantes', '47.21725', '-1.55336'),
#  (26, 23, 'Nancy', '48.68439', '6.18496'),
#  (24, 24, 'Mulhouse', '47.75', '7.33333'),
#  (19, 20, 'Montpellier', '43.61092', '3.87723'),
#  (26, 23, 'Metz', '49.11911', '6.17269'),
#  (18, 21, 'Marseille', '43.29695', '5.38107'),
#  (22, 21, 'Lyon', '45.74846', '4.84671'),
#  (23, 18, 'Limoges', '45.83153', '1.25781'),
#  (29, 21, 'Lille', '50.63297', '3.05858'),
#  (26, 17, 'Le Mans', '48', '0.2'),
#  (28, 18, 'Le Havre', '49.4938', '0.10767'),
#  (21, 22, 'Grenoble', '45.16667', '5.71667'),
#  (24, 22, 'Dijon', '47.31667', '5.01667'),
#  (22, 20, 'Clermont-Ferrand', '45.77966', '3.08628'),
#  (28, 17, 'Caen', '49.18585', '-0.35912'),
#  (27, 13, 'Brest', '48.39029', '-4.48628'),
#  (27, 20, 'Boulogne-Billancourt', '48.83333', '2.25'),
#  (22, 16, 'Bordeaux', '44.84044', '-0.5805'),
#  (24, 23, 'Besancon', '47.24878', '6.01815'),
#  (27, 20, 'Argenteuil', '48.95', '2.25'),
#  (25, 16, 'Angers', '47.46667', '-0.55'),
#  (28, 20, 'Amiens', '49.9', '2.3'),
#  (19, 21, 'Aix-en-Provence', '43.5283', '5.44973'),
#  (27, 19, 'Saint-Quentin-en-Yvelines', '48.77186', '2.01891'),
#  (27, 19, 'Cergy-Pontoise', '49.03894', '2.07805'),
#  (34, 18, 'York', '53.95763', '-1.08271'),
#  (32, 17, 'Worcester', '52.18935', '-2.22001'),
#  (33, 17, 'Wolverhampton', '52.58547', '-2.12296'),
#  (31, 18, 'Woking', '51.31903', '-0.55893'),
#  (34, 17, 'Wigan', '53.54296', '-2.63706'),
#  (33, 17, 'West Bromwich', '52.51868', '-1.9945'),
#  (31, 18, 'Watford', '51.65531', '-0.39602'),
#  (34, 17, 'Warrington', '53.39254', '-2.58024'),
#  (33, 17, 'Walsall', '52.58528', '-1.98396'),
#  (31, 17, 'Swindon', '51.55797', '-1.78116'),
#  (32, 15, 'Swansea', '51.62079', '-3.94323'),
#  (33, 17, 'Sutton Coldfield', '52.56667', '-1.81667'),
#  (31, 18, 'Sutton', '51.35', '-0.2'),
#  (36, 18, 'Sunderland', '54.90465', '-1.38222'),
#  (33, 17, 'Stoke-on-Trent', '53.00415', '-2.18538'),
#  (34, 17, 'Stockport', '53.40979', '-2.15761'),
#  (31, 19, 'Southend-on-Sea', '51.53782', '0.71433'),
#  (30, 17, 'Southampton', '50.90395', '-1.40428'),
#  (31, 18, 'Slough', '51.50949', '-0.59541'),
#  (34, 18, 'Sheffield', '53.38297', '-1.4659'),
#  (30, 19, 'Saint Peters', '51.36667', '1.41667'),
#  (34, 17, 'St Helens', '53.45', '-2.73333'),
#  (34, 18, 'Rotherham', '53.43012', '-1.35678'),
#  (31, 17, 'Reading', '51.45625', '-0.97113'),
#  (34, 17, 'Preston', '53.76282', '-2.70452'),
#  (30, 17, 'Portsmouth', '50.79899', '-1.09125'),
#  (30, 16, 'Poole', '50.71429', '-1.98458'),
#  (30, 14, 'Plymouth', '50.37153', '-4.14305'),
#  (32, 18, 'Peterborough', '52.57364', '-0.24777'),
#  (31, 17, 'Oxford', '51.75222', '-1.25596'),
#  (34, 17, 'Oldham', '53.54051', '-2.1183'),
#  (33, 18, 'Nottingham', '52.9536', '-1.15047'),
#  (32, 20, 'Norwich', '52.62783', '1.29834'),
#  (32, 18, 'Northampton', '52.25', '-0.88333'),
#  (32, 16, 'Newport', '51.58774', '-2.99835'),
#  (36, 18, 'Newcastle upon Tyne', '54.97328', '-1.61396'),
#  (32, 18, 'Milton Keynes', '52.04172', '-0.75583'),
#  (35, 18, 'Middlesbrough', '54.57623', '-1.23483'),
#  (33, 18, 'Mansfield', '53.13333', '-1.2'),
#  (34, 17, 'Manchester', '53.48095', '-2.23743'),
#  (30, 19, 'Maidstone', '51.26667', '0.51667'),
#  (31, 18, 'Luton', '51.87967', '-0.41748'),
#  (31, 18, 'London', '51.50853', '-0.12574'),
#  (34, 16, 'Liverpool', '53.41058', '-2.97794'),
#  (33, 18, 'Lincoln', '53.22683', '-0.53792'),
#  (33, 18, 'Leicester', '52.6386', '-1.13169'),
#  (34, 18, 'Leeds', '53.79648', '-1.54785'),
#  (34, 19, 'Kingston upon Hull', '53.7446', '-0.33525'),
#  (31, 18, 'Islington', '51.53622', '-0.10304'),
#  (31, 19, 'Ipswich', '52.05917', '1.15545'),
#  (34, 17, 'Huddersfield', '53.64904', '-1.78416'),
#  (31, 18, 'High Wycombe', '51.62907', '-0.74934'),
#  (30, 19, 'Hastings', '50.85519', '0.57292'),
#  (34, 19, 'Grimsby', '53.56539', '-0.07553'),
#  (32, 16, 'Gloucester', '51.86568', '-2.2431'),
#  (38, 16, 'Glasgow', '55.86515', '-4.25763'),
#  (31, 19, 'Gillingham', '51.38914', '0.54863'),
#  (30, 15, 'Exeter', '50.7236', '-3.52751'),
#  (31, 18, 'Enfield Town', '51.65147', '-0.08497'),
#  (38, 17, 'Edinburgh', '55.95206', '-3.19648'),
#  (30, 18, 'Eastbourne', '50.76871', '0.28453'),
#  (38, 17, 'Dundee', '56.46913', '-2.97489'),
#  (33, 17, 'Dudley', '52.5', '-2.08333'),
#  (34, 18, 'Doncaster', '53.52285', '-1.13116'),
#  (33, 17, 'Derby', '52.92277', '-1.47663'),
#  (31, 18, 'Dagenham', '51.55', '0.16667'),
#  (31, 18, 'Croydon', '51.38333', '-0.1'),
#  (30, 18, 'Crawley', '51.11303', '-0.18312'),
#  (32, 17, 'Coventry', '52.40656', '-1.51217'),
#  (31, 19, 'Colchester', '51.88921', '0.90421'),
#  (33, 18, 'Chesterfield', '53.25', '-1.41667'),
#  (32, 17, 'Cheltenham', '51.90006', '-2.07972'),
#  (31, 19, 'Chelmsford', '51.73575', '0.46958'),
#  (31, 15, 'Cardiff', '51.48', '-3.18'),
#  (32, 19, 'Cambridge', '52.2', '0.11667'),
#  (33, 17, 'Burton upon Trent', '52.80728', '-1.64263'),
#  (34, 17, 'Burnley', '53.8', '-2.23333'),
#  (31, 16, 'Bristol', '51.45523', '-2.59665'),
#  (30, 18, 'Brighton', '50.82838', '-0.13947'),
#  (34, 17, 'Bradford', '53.79391', '-1.75206'),
#  (30, 16, 'Bournemouth', '50.72048', '-1.8795'),
#  (34, 17, 'Bolton', '53.58333', '-2.43333'),
#  (35, 16, 'Blackpool', '53.81667', '-3.05'),
#  (34, 17, 'Blackburn', '53.75', '-2.48333'),
#  (33, 17, 'Birmingham', '52.48142', '-1.89983'),
#  (34, 16, 'Birkenhead', '53.39337', '-3.01479'),
#  (31, 18, 'Bexley', '51.44162', '0.14866'),
#  (36, 14, 'Belfast', '54.59682', '-5.92541'),
#  (32, 18, 'Bedford', '52.13459', '-0.46632'),
#  (31, 17, 'Basingstoke', '51.26249', '-1.08708'),
#  (31, 19, 'Basildon', '51.56844', '0.45782'),
#  (39, 18, 'Aberdeen', '57.14369', '-2.09814'),
#  (33, 17, 'Telford', '52.67659', '-2.44926'),
#  (31, 18, 'Becontree', '51.5529', '0.129'),
#  (31, 16, 'Mendip', '51.2372', '-2.6266'),
#  (31, 18, 'Archway', '51.56733', '-0.13415'),
#  (10, 42, 'Piraeus', '37.94745', '23.63708'),
#  (10, 42, 'Peristeri', '38.01539', '23.69187'),
#  (10, 39, 'Patra', '38.24444', '21.73444'),
#  (13, 40, 'Larisa', '39.63689', '22.41761'),
#  (10, 42, 'Kallithea', '37.95', '23.7'),
#  (7, 44, 'Irakleion', '35.32787', '25.14341'),
#  (10, 42, 'Athens', '37.97945', '23.71622'),
#  (14, 40, 'Thessaloniki', '40.64361', '22.93086'),
#  (21, 32, 'Zagreb', '45.81444', '15.97798'),
#  (18, 33, 'Split', '43.50891', '16.43915'),
#  (20, 31, 'Rijeka', '45.32673', '14.44241'),
#  (22, 37, 'Szeged', '46.253', '20.14824'),
#  (25, 38, 'Nyiregyhaza', '47.95539', '21.71671'),
#  (25, 37, 'Miskolc', '48.1', '20.78333'),
#  (24, 38, 'Debrecen', '47.53333', '21.63333'),
#  (24, 35, 'Zuglo', '47.51758', '19.10549'),
#  (23, 35, 'Szekesfehervar', '47.18995', '18.41034'),
#  (22, 35, 'Pecs', '46.08333', '18.23333'),
#  (23, 36, 'Kecskemet', '46.90618', '19.69128'),
#  (24, 34, 'Gyor', '47.68333', '17.63512'),
#  (24, 35, 'Budapest', '47.49801', '19.03991'),
#  (24, 35, 'Budapest XI. keruelet', '47.47603', '19.03605'),
#  (24, 35, 'Budapest XIII. keruelet', '47.52978', '19.08068'),
#  (24, 35, 'Budapest III. keruelet', '47.54157', '19.04501'),
#  (35, 14, 'Dun Laoghaire', '53.29395', '-6.13586'),
#  (35, 14, 'Dublin', '53.33306', '-6.24889'),
#  (33, 11, 'Cork', '51.89797', '-8.47061'),
#  (10, 32, 'Reggio Calabria', '38.11047', '15.66129'),
#  (10, 30, 'Palermo', '38.13205', '13.33561'),
#  (10, 32, 'Messina', '38.19394', '15.55256'),
#  (9, 32, 'Catania', '37.49223', '15.07041'),
#  (12, 25, 'Cagliari', '39.23054', '9.11917'),
#  (21, 28, 'Vicenza', '45.54672', '11.5475'),
#  (21, 27, 'Verona', '45.4299', '10.98444'),
#  (21, 30, 'Trieste', '45.64953', '13.77678'),
#  (20, 24, 'Turin', '45.07049', '7.68682'),
#  (13, 34, 'Taranto', '40.46438', '17.24707'),
#  (14, 31, 'Salerno', '40.67545', '14.79328'),
#  (16, 29, 'Rome', '41.89193', '12.51133'),
#  (19, 29, 'Rimini', '44.05755', '12.56528'),
#  (20, 27, "Reggio nell'Emilia", '44.69825', '10.63125'),
#  (18, 27, 'Prato', '43.8805', '11.09699'),
#  (16, 31, 'Pescara', '42.4584', '14.20283'),
#  (17, 29, 'Perugia', '43.1122', '12.38878'),
#  (20, 27, 'Parma', '44.79935', '10.32618'),
#  (21, 28, 'Padova', '45.40797', '11.88586'),
#  (14, 31, 'Naples', '40.85216', '14.26811'),
#  (21, 26, 'Monza', '45.58005', '9.27246'),
#  (20, 27, 'Modena', '44.64783', '10.92539'),
#  (21, 26, 'Milan', '45.46427', '9.18951'),
#  (21, 29, 'Mestre', '45.49167', '12.24538'),
#  (18, 27, 'Livorno', '43.54427', '10.32615'),
#  (19, 25, 'Genoa', '44.40478', '8.94439'),
#  (15, 32, 'Foggia', '41.45845', '15.55188'),
#  (18, 28, 'Florence', '43.77925', '11.24626'),
#  (21, 27, 'Brescia', '45.53558', '10.21472'),
#  (19, 28, 'Bologna', '44.49381', '11.33875'),
#  (21, 26, 'Bergamo', '45.69601', '9.66721'),
#  (14, 34, 'Bari', '41.11148', '16.8554'),
#  (15, 29, 'Acilia-Castel Fusano-Ostia Antica', '41.76337', '12.33078'),
#  (35, 40, 'Vilnius', '54.68916', '25.2798'),
#  (36, 38, 'Siauliai', '55.93333', '23.31667'),
#  (36, 39, 'Panevezys', '55.73333', '24.35'),
#  (36, 36, 'Klaipeda', '55.70888', '21.14312'),
#  (35, 39, 'Kaunas', '54.90272', '23.90961'),
#  (38, 39, 'Riga', '56.946', '24.10589'),
#  (36, 41, 'Daugavpils', '55.88333', '26.53333'),
#  (10, 7, 'Tetouan', '35.57845', '-5.36837'),
#  (7, 8, 'Taza', '34.21', '-4.01'),
#  (10, 7, 'Tangier', '35.76727', '-5.79975'),
#  (7, 11, 'Oujda-Angad', '34.68139', '-1.90858'),
#  (8, 10, 'Nador', '35.16813', '-2.93352'),
#  (9, 6, 'Larache', '35.19321', '-6.15572'),
#  (9, 6, 'Ksar El Kebir', '35.00044', '-5.90378'),
#  (8, 5, 'Kenitra', '34.26101', '-6.5802'),
#  (9, 9, 'Al Hoceima', '35.25165', '-3.93723'),
#  (24, 46, 'Tiraspol', '46.84274', '29.62909'),
#  (24, 45, 'Chisinau', '47.00556', '28.8575'),
#  (24, 46, 'Bender', '46.83156', '29.47769'),
#  (25, 44, 'Balti', '47.76314', '27.92932'),
#  (16, 36, 'Podgorica', '42.44111', '19.26361'),
#  (16, 38, 'Skopje', '41.99646', '21.43141'),
#  (31, 24, 'Zwolle', '52.5125', '6.09444'),
#  (31, 22, 'Zoetermeer', '52.0575', '4.49306'),
#  (31, 23, 'Zaanstad', '52.45313', '4.81356'),
#  (31, 23, 'Utrecht', '52.09083', '5.12222'),
#  (30, 23, 'Tilburg', '51.55551', '5.0913'),
#  (30, 23, "'s-Hertogenbosch", '51.69917', '5.30417'),
#  (31, 22, 'The Hague', '52.07667', '4.29861'),
#  (31, 22, 'Rotterdam', '51.9225', '4.47917'),
#  (30, 23, 'Nijmegen', '51.8425', '5.85278'),
#  (29, 23, 'Maastricht', '50.84833', '5.68889'),
#  (31, 22, 'Leiden', '52.15833', '4.49306'),
#  (31, 23, 'Hoofddorp', '52.3025', '4.68889'),
#  (31, 22, 'Haarlem', '52.38084', '4.63683'),
#  (32, 24, 'Groningen', '53.21917', '6.56667'),
#  (31, 24, 'Enschede', '52.21833', '6.89583'),
#  (30, 23, 'Eindhoven', '51.44083', '5.47778'),
#  (30, 22, 'Dordrecht', '51.81', '4.67361'),
#  (30, 22, 'Breda', '51.58656', '4.77596'),
#  (31, 24, 'Arnhem', '51.98', '5.91111'),
#  (31, 24, 'Apeldoorn', '52.21', '5.96944'),
#  (31, 23, 'Amsterdam', '52.37403', '4.88969'),
#  (31, 23, 'Amersfoort', '52.155', '5.3875'),
#  (31, 23, 'Almere Stad', '52.37025', '5.21413'),
#  (31, 37, 'Wola', '52.2401', '20.98869'),
#  (31, 37, 'Warsaw', '52.22977', '21.01178'),
#  (27, 37, 'Tarnow', '50.01381', '20.98698'),
#  (31, 37, 'Targowek', '52.29185', '21.04845'),
#  (31, 37, 'Srodmiescie', '52.22904', '21.01644'),
#  (28, 38, 'Rzeszow', '50.04132', '21.99901'),
#  (29, 37, 'Radom', '51.40253', '21.14714'),
#  (33, 36, 'Olsztyn', '53.77995', '20.49416'),
#  (31, 37, 'Mokotow', '52.1934', '21.03487'),
#  (29, 38, 'Lublin', '51.25', '22.56667'),
#  (29, 37, 'Kielce', '50.87033', '20.62752'),
#  (31, 37, 'Bielany', '52.29242', '20.93531'),
#  (32, 38, 'Bialystok', '53.13333', '23.16433'),
#  (31, 37, 'Bemowo', '52.2546', '20.90844'),
#  (30, 32, 'Zielona Gora', '51.93548', '15.50643'),
#  (28, 35, 'Zabrze', '50.32492', '18.78576'),
#  (29, 33, 'Wroclaw', '51.1', '17.03333'),
#  (31, 35, 'Wloclawek', '52.64817', '19.0678'),
#  (28, 33, 'Walbrzych', '50.77141', '16.28432'),
#  (28, 35, 'Tychy', '50.13717', '18.96641'),
#  (32, 35, 'Torun', '53.01375', '18.59814'),
#  (32, 31, 'Szczecin', '53.42894', '14.55302'),
#  (28, 35, 'Sosnowiec', '50.28682', '19.10385'),
#  (27, 35, 'Rybnik', '50.09713', '18.54179'),
#  (28, 35, 'Ruda Slaska', '50.2584', '18.85632'),
#  (31, 33, 'Poznan', '52.40692', '16.92993'),
#  (31, 36, 'Plock', '52.54682', '19.70638'),
#  (28, 34, 'Opole', '50.67211', '17.92533'),
#  (30, 35, 'Lodz', '51.75', '19.46667'),
#  (29, 33, 'Legnica', '51.21006', '16.1619'),
#  (27, 36, 'Krakow', '50.06143', '19.93658'),
#  (33, 32, 'Koszalin', '54.19438', '16.17222'),
#  (28, 35, 'Katowice', '50.25841', '19.02754'),
#  (30, 34, 'Kalisz', '51.76109', '18.09102'),
#  (31, 32, 'Gorzow Wielkopolski', '52.73679', '15.22878'),
#  (28, 35, 'Gliwice', '50.29761', '18.67658'),
#  (34, 34, 'Gdynia', '54.51889', '18.53188'),
#  (34, 35, 'Gdansk', '54.35205', '18.64637'),
#  (33, 35, 'Elblag', '54.1522', '19.40884'),
#  (28, 35, 'Dabrowa Gornicza', '50.31818', '19.2374'),
#  (28, 35, 'Czestochowa', '50.79646', '19.12409'),
#  (28, 35, 'Chorzow', '50.30582', '18.9742'),
#  (28, 35, 'Bytom', '50.34802', '18.93282'),
#  (32, 34, 'Bydgoszcz', '53.1235', '18.00762'),
#  (27, 35, 'Bielsko-Biala', '49.82245', '19.04686'),
#  (31, 37, 'Ursynow', '52.15051', '21.05041'),
#  (31, 37, 'Praga Poludnie', '52.24424', '21.08545'),
#  (15, 4, 'Setubal', '38.5244', '-8.8882'),
#  (16, 4, 'Queluz', '38.75657', '-9.25451'),
#  (16, 4, 'Lisbon', '38.71667', '-9.13333'),
#  (16, 4, 'Amadora', '38.75382', '-9.23083'),
#  (19, 6, 'Porto', '41.14961', '-8.61099'),
#  (17, 6, 'Coimbra', '40.20564', '-8.41955'),
#  (19, 6, 'Braga', '41.55032', '-8.42005'),
#  (23, 41, 'Targu-Mures', '46.54245', '24.55747'),
#  (21, 38, 'Timisoara', '45.75372', '21.22571'),
#  (25, 42, 'Suceava', '47.63333', '26.25'),
#  (22, 41, 'Sibiu', '45.8', '24.15'),
#  (24, 39, 'Satu Mare', '47.79926', '22.86255'),
#  (21, 41, 'Ramnicu Valcea', '45.1', '24.36667'),
#  (21, 43, 'Ploiesti', '44.95', '26.01667'),
#  (20, 42, 'Pitesti', '44.85', '24.86667'),
#  (24, 43, 'Piatra Neamt', '46.91667', '26.33333'),
#  (23, 38, 'Oradea', '47.0458', '21.91833'),
#  (24, 44, 'Iasi', '47.16667', '27.6'),
#  (22, 45, 'Galati', '45.45', '28.05'),
#  (20, 39, 'Drobeta-Turnu Severin', '44.63194', '22.65611'),
#  (20, 41, 'Craiova', '44.31667', '23.8'),
#  (20, 46, 'Constanta', '44.18073', '28.63432'),
#  (23, 40, 'Cluj-Napoca', '46.76667', '23.6'),
#  (21, 44, 'Buzau', '45.15', '26.83333'),
#  (20, 43, 'Bucharest', '44.43225', '26.10626'),
#  (22, 42, 'Brasov', '45.64861', '25.60613'),
#  (22, 45, 'Braila', '45.26667', '27.98333'),
#  (25, 43, 'Botosani', '47.75', '26.66667'),
#  (24, 40, 'Baia Mare', '47.65729', '23.56808'),
#  (23, 43, 'Bacau', '46.56718', '26.91384'),
#  (22, 38, 'Arad', '46.18333', '21.31667'),
#  (20, 43, 'Sector 1', '44.49239', '26.04831'),
#  (20, 43, 'Sector 2', '44.4528', '26.13321'),
#  (20, 43, 'Sector 3', '44.4234', '26.16874'),
#  (20, 43, 'Sector 4', '44.37571', '26.12085'),
#  (20, 43, 'Sector 5', '44.38808', '26.07144'),
#  (20, 43, 'Sector 6', '44.43579', '26.01649'),
#  (20, 37, 'Zemun', '44.84306', '20.40111'),
#  (18, 39, 'Nis', '43.32472', '21.90333'),
#  (19, 38, 'Kragujevac', '44.01667', '20.91667'),
#  (19, 37, 'Cacak', '43.89139', '20.34972'),
#  (20, 37, 'Belgrade', '44.80401', '20.46513'),
#  (22, 36, 'Subotica', '46.1', '19.66667'),
#  (21, 36, 'Novi Sad', '45.25167', '19.83694'),
#  (39, 42, 'Pskov', '57.8136', '28.3496'),
#  (34, 36, 'Kaliningrad', '54.70649', '20.51095'),
#  (35, 30, 'Malmoe', '55.60587', '13.00073'),
#  (36, 30, 'Helsingborg', '56.04673', '12.69437'),
#  (38, 29, 'Goeteborg', '57.70716', '11.96679'),
#  (22, 31, 'Ljubljana', '46.05108', '14.50513'),
#  (26, 37, 'Kosice', '48.71395', '21.25808'),
#  (25, 34, 'Bratislava', '48.14816', '17.10674'),
#  (8, 26, 'Tunis', '36.81897', '10.16579'),
#  (7, 26, 'Sousse', '35.82539', '10.63699'),
#  (5, 26, 'Sfax', '34.74056', '10.76028'),
#  (9, 25, 'Bizerte', '37.27442', '9.87391'),
#  (7, 26, 'Kairouan', '35.6781', '10.09633'),
#  (12, 48, 'Usak', '38.67351', '29.4058'),
#  (12, 46, 'Turgutlu', '38.49533', '27.6997'),
#  (11, 47, 'Nazilli', '37.91631', '28.32225'),
#  (12, 46, 'Manisa', '38.61202', '27.42647'),
#  (12, 46, 'Izmir', '38.41273', '27.13838'),
#  (11, 48, 'Denizli', '37.77417', '29.0875'),
#  (14, 46, 'Balikesir', '39.64917', '27.88611'),
#  (11, 46, 'Aydin', '37.84501', '27.83963'),
#  (16, 47, 'Zeytinburnu', '40.99441', '28.90417'),
#  (16, 47, 'UEskuedar', '41.02252', '29.02369'),
#  (16, 47, 'Umraniye', '41.01643', '29.12476'),
#  (15, 45, 'Tekirdag', '40.9781', '27.51101'),
#  (16, 47, 'Sisli', '41.06046', '28.98717'),
#  (14, 47, 'Mustafakemalpasa', '40.03815', '28.40866'),
#  (16, 47, 'Maltepe', '40.93567', '29.15507'),
#  (16, 47, 'Istanbul', '41.01384', '28.94966'),
#  (14, 48, 'Inegol', '40.07806', '29.51333'),
#  (16, 47, 'Gebze', '40.80276', '29.43068'),
#  (16, 47, 'Esenyurt', '41.02697', '28.67732'),
#  (16, 47, 'Esenler', '41.0435', '28.87619'),
#  (16, 44, 'Edirne', '41.67719', '26.55597'),
#  (16, 46, 'Corlu', '41.15917', '27.8'),
#  (15, 47, 'Bursa', '40.19559', '29.06013'),
#  (15, 46, 'Bandirma', '40.35222', '27.97667'),
#  (16, 47, 'Bagcilar', '41.03903', '28.85671'),
#  (16, 47, 'Atasehir', '40.9833', '29.1167'),
#  (16, 47, 'Basaksehir', '41.09307', '28.80203'),
#  (16, 46, 'Beylikduezue', '40.982', '28.6399'),
#  (16, 46, 'Bueyuekcekmece', '41.02072', '28.58502'),
#  (16, 47, 'Bahcelievler', '41.00231', '28.8598'),
#  (16, 47, 'Sultangazi', '41.10652', '28.86847'),
#  (16, 47, 'Sultanbeyli', '40.96072', '29.27067'),
#  (16, 47, 'Sancaktepe', '41.00244', '29.23187'),
#  (12, 46, 'Karabaglar', '38.37396', '27.1352'),
#  (11, 48, 'Merkezefendi', '37.80544', '29.04236'),
#  (29, 44, 'Zhytomyr', '50.26487', '28.67669'),
#  (27, 44, 'Vinnytsia', '49.23278', '28.48097'),
#  (26, 38, 'Uzhgorod', '48.61667', '22.3'),
#  (27, 41, 'Ternopil', '49.55342', '25.58918'),
#  (29, 42, 'Rivne', '50.62308', '26.22743'),
#  (28, 40, 'Lviv', '49.83826', '24.02324'),
#  (29, 41, 'Lutsk', '50.75932', '25.34244'),
#  (27, 43, 'Khmelnytskyi', '49.42161', '26.99653'),
#  (26, 42, 'Kamianets-Podilskyi', '48.6845', '26.58559'),
#  (26, 41, 'Ivano-Frankivsk', '48.9215', '24.70972'),
#  (26, 42, 'Chernivtsi', '48.29149', '25.94034'),
#  (16, 38, 'Prizren', '42.21389', '20.73972'),
#  (17, 38, 'Pristina', '42.67272', '21.16688'),
#  (17, 38, 'Mitrovice', '42.88333', '20.86667')]

# %%
def windiest_cities(q,all_weathers_mags = all_weathers_mags):
    
    windiest_cities=[]
    counter = 0
    
    if q == 'q1':
        season = np.concatenate((all_weathers_mags[0:28, :, :, :], all_weathers_mags[112:140, :, :, :]), axis=0) 
    elif q == 'q2':
        season = np.concatenate((all_weathers_mags[28:56, :, :, :], all_weathers_mags[140:168, :, :, :]), axis=0)
    elif q == 'q3':
        season = np.concatenate((all_weathers_mags[56:84, :, :, :], all_weathers_mags[168:196, :, :, :]), axis=0)
    elif q == 'q4':
        season = np.concatenate((all_weathers_mags[84:112, :, :, :], all_weathers_mags[196:224, :, :, :]), axis=0)
    
    short = np.argpartition(-season[:,2].flatten(), season.shape) 
    
    for every in short: 
        max_index = np.unravel_index(every, season.shape)
        for country in cities_grid:
            if country[0] == max_index[2] and country[1] == max_index[3]:
                country_tuple = (country[2], float(country[3]), float(country[4]))
                windiest_cities.append(country_tuple)
                counter = counter + 1
                break

        if counter == 10:
            break
            
    return windiest_cities

# %%
q1_cities = windiest_cities('q1', all_weathers_mags)
q2_cities = windiest_cities('q2', all_weathers_mags)
q3_cities = windiest_cities('q3', all_weathers_mags)
q4_cities = windiest_cities('q4', all_weathers_mags)

# %%
q1_cities
# Out:
# [('Kiel', 54.32133, 10.13489),
#  ('Odense', 55.39594, 10.38831),
#  ('Copenhagen', 55.67594, 12.56553),
#  ('Bremerhaven', 53.55021, 8.57673),
#  ('Helsingborg', 56.04673, 12.69437),
#  ('Arhus', 56.15674, 10.21076),
#  ('Groningen', 53.21917, 6.56667),
#  ('Luebeck', 53.86893, 10.68729),
#  ('Aalborg', 57.048, 9.9187),
#  ('Oldenburg', 53.14118, 8.21467)]

# %%
q2_cities
# Out:
# [('Nazilli', 37.91631, 28.32225),
#  ('Denizli', 37.77417, 29.0875),
#  ('Aydin', 37.84501, 27.83963),
#  ('Plovdiv', 42.15, 24.75),
#  ('Stara Zagora', 42.43278, 25.64194),
#  ('Burgas', 42.50606, 27.46781),
#  ('Varna', 43.21667, 27.91667),
#  ('Constanta', 44.18073, 28.63432),
#  ('Buzau', 45.15, 26.83333),
#  ('Galati', 45.45, 28.05)]

# %%
q3_cities
# Out:
# [('Sfax', 34.74056, 10.76028),
#  ('Djelfa', 34.67279, 3.263),
#  ('Biskra', 34.85038, 5.72805),
#  ('Khenchela', 35.43583, 7.14333),
#  ('Tebessa', 35.40417, 8.12417),
#  ('Taza', 34.21, -4.01),
#  ('Oujda-Angad', 34.68139, -1.90858),
#  ('Tlemcen', 34.87833, -1.315),
#  ('Saida', 34.83033, 0.15171),
#  ('Tiaret', 35.37103, 1.31699)]

# %%
q4_cities
# Out:
# [('Tiraspol', 46.84274, 29.62909),
#  ('Iasi', 47.16667, 27.6),
#  ('Bacau', 46.56718, 26.91384),
#  ('Balti', 47.76314, 27.92932),
#  ('Chisinau', 47.00556, 28.8575),
#  ('Zemun', 44.84306, 20.40111),
#  ('Timisoara', 45.75372, 21.22571),
#  ('Ploiesti', 44.95, 26.01667),
#  ('Buzau', 45.15, 26.83333),
#  ('Szeged', 46.253, 20.14824)]

# %% [markdown]
# **(10) The function below displays a 64x64 data array onto a map. Change it so that it also displays a list of points - you will use this functionality to display city locations. Use your new function to display wind magnitude average and the 10 windiest cities per season. [2 marks]**
#
# *Hint: You will need to create 4 maps, one per season.*

# %%
# %matplotlib inline

def display_on_map(q, data, title=None, lat=lat, lon=lon):
    
    if q == 'q1':
        cities = q1_cities 
    elif q == 'q2':
        cities = q2_cities
    elif q == 'q3':
        cities = q3_cities
    elif q == 'q4':
        cities = q4_cities
      
         
    im = plt.imread('map-pin.png')

    m = Basemap(width=3800E3, height=3800E3,
                resolution='l', projection='lcc', lat_0 = 50, 
                lon_0 = 10, lat_ts = 40, k_0=1.0)
    m.drawcoastlines(linewidth=1.0, color='#444444')
    m.drawcountries(linewidth=1.0, color='#444444')
    m.drawmapboundary(linewidth=1.0, color='#000000')
    
    x, y = m(lon, lat)
    try:
        pass
        cs = m.contour(x, y, data, linewidths=1.0, colors='k')
    except:
        pass
    pcl = m.pcolor(x, y, np.squeeze(data))
    cbar = m.colorbar(pcl, location='bottom', pad='2%')
     
    for city in cities:
        latitude = city[1]
        longtitude = city[2]
        x1, y1 = m(longtitude, latitude)
        m.plot(x1, y1, marker = 'D', color='r')

    if title:
        plt.title(title)
    plt.show()

# %%
plt.figure(figsize=(18, 18))
display_on_map('q1', data[0,4][0,0], title = "Map for 1st quarter:")

# %%
plt.figure(figsize=(18, 18))
display_on_map('q2', data[0,4][0,0], title = "Map for 2nd quarter:")

# %%
plt.figure(figsize=(18, 18))
display_on_map('q3', data[0,4][0,0], title = "Map for 3rd quarter:")

# %%
plt.figure(figsize=(18, 18))
display_on_map('q4', data[0,4][0,0], title = "Map for 4th quarter:")
